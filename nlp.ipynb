# %%
import pandas as pd 
import numpy as np 
import re 
import sys

# %%
itTicketDF=pd.read_excel('IT-Ticket-Classification.xlsx')
itTicketDF.head()
# Out:
#                Short description  \
# 0                    login issue
# 1                        outlook
# 2             cant log in to vpn
# 3  unable to access hr_tool page
# 4                   skype error
#
#                                          Description             Caller  \
# 0  -verified user details.(employee# & manager na...  spxjnwir pjlcoqds
# 1  \r\n\r\nreceived from: hmjdrvpb.komuaywn@gmail...  hmjdrvpb komuaywn
# 2  \r\n\r\nreceived from: eylqgodm.ybqkwiam@gmail...  eylqgodm ybqkwiam
# 3                      unable to access hr_tool page  xbkucsvz gcpydteq
# 4                                       skype error   owlgqjme qhcozdfx
#
#   Assignment group
# 0            GRP_0
# 1            GRP_0
# 2            GRP_0
# 3            GRP_0
# 4            GRP_0

# %%
callers = itTicketDF['Caller'].unique() 
display(callers.shape)
itTicketDF.drop(["Caller",'Short description'],axis=1,inplace= True)
itTicketDF.info()
# Out:
# (2950,)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8500 entries, 0 to 8499
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Description       8499 non-null   object
#  1   Assignment group  8500 non-null   object
# dtypes: object(2)
# memory usage: 132.9+ KB

# %%
targetClassCnt=itTicketDF['Assignment group'].value_counts()
targetClassCnt.describe()
# Out:
# count      74.000000
# mean      114.864865
# std       465.747516
# min         1.000000
# 25%         5.250000
# 50%        26.000000
# 75%        84.000000
# max      3976.000000
# Name: Assignment group, dtype: float64

# %% [markdown]
# #### Observation
# Appears the Target class distrubtion is extremely skewed
# Large no of entries for GRP_0 (mounting to 3976) which account for ~50% of the data
# there are groups with 1 entry also. We could merge all groups with small entries to a group to reduce the imbalance in the target. This may reduce the imbalance to some extent.

# %%
sample = itTicketDF.groupby(['Assignment group'])
regroup=[]
for grp in itTicketDF['Assignment group'].unique():
    if(sample.get_group(grp).shape[0]<10):
        regroup.append(grp)
print('Found {} groups which have under 10 samples'.format(len(regroup)))
itTicketDF['Assignment group']=itTicketDF['Assignment group'].apply(lambda x : 'misc_grp' if x in regroup  else x)

# Unique Groups check 
itTicketDF['Assignment group'].unique()
# Out:
# Found 25 groups which have under 10 samples
# array(['GRP_0', 'GRP_1', 'GRP_3', 'GRP_4', 'GRP_5', 'GRP_6', 'GRP_7',
#        'GRP_8', 'GRP_9', 'GRP_10', 'GRP_11', 'GRP_12', 'GRP_13', 'GRP_14',
#        'GRP_15', 'GRP_16', 'GRP_17', 'GRP_18', 'GRP_19', 'GRP_2',
#        'GRP_20', 'GRP_21', 'GRP_22', 'GRP_23', 'GRP_24', 'GRP_25',
#        'GRP_26', 'GRP_27', 'GRP_28', 'GRP_29', 'GRP_30', 'GRP_31',
#        'GRP_33', 'GRP_34', 'misc_grp', 'GRP_36', 'GRP_37', 'GRP_39',
#        'GRP_40', 'GRP_41', 'GRP_42', 'GRP_44', 'GRP_45', 'GRP_47',
#        'GRP_48', 'GRP_50', 'GRP_53', 'GRP_60', 'GRP_62', 'GRP_65'],
#       dtype=object)

# %%
##Pre-Processing label Encoding on  Assignment Group
import seaborn as sns
import matplotlib.pyplot as plt
#add to remove warning for python 3.6 dependency
import warnings
import pandas.util.testing as tm
plt.style.use('ggplot')
# %matplotlib inline

descending_order = itTicketDF['Assignment group'].value_counts().sort_values(ascending=False).index
plt.subplots(figsize=(22,5))
#added code for x label rotate 
ax=sns.countplot(x='Assignment group', data=itTicketDF, color='royalblue',order=descending_order)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-ca72a9c3bdac>:6: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Fill 'Decsription' field entries that have null with blank space
itTicketDF['Description'].fillna(value=' ', inplace=True)

# %%
from dateutil import parser
def is_valid_date(date_str):
    try:
        parser.parse(date_str)
        return True
    except:
        return False

# %%
def clean_data(text):
    text=text.lower()
    text = ' '.join([w for w in text.split() if not is_valid_date(w)])
    text = re.sub(r"received from:",' ',text)
    text = re.sub(r"from:",' ',text)
    text = re.sub(r"to:",' ',text)
    text = re.sub(r"subject:",' ',text)
    text = re.sub(r"sent:",' ',text)
    text = re.sub(r"ic:",' ',text)
    text = re.sub(r"cc:",' ',text)
    text = re.sub(r"bcc:",' ',text)
    #Remove email 
    text = re.sub(r'\S*@\S*\s?', '', text)
    # Remove numbers 
    text = re.sub(r'\d+','' ,text)
    # Remove Non Dictionary character-TODO
    # Remove new line characters 
    text = re.sub(r'\n',' ',text)
    # Remove hashtag while keeping hashtag text
    text = re.sub(r'#','', text)
    #& 
    text = re.sub(r'&;?', 'and',text)
    # Remove HTML special entities (e.g. &amp;)
    text = re.sub(r'\&\w*;', '', text)
    # Remove hyperlinks
    text = re.sub(r'https?:\/\/.*\/\w*', '', text)  
    # Remove characters beyond Readable formart by Unicode:
    text= ''.join(c for c in text if c <= '\uFFFF') 
    text = text.strip()
    # Remove unreadable characters  (also extra spaces)
    text = ' '.join(re.sub("[^\u0030-\u0039\u0041-\u005a\u0061-\u007a]", " ", text).split())
    for name in callers:
        namelist = [part for part in name.split()]
        for namepart in namelist: 
            text = text.replace(namepart,'')
          
    text = re.sub(r"\s+[a-zA-Z]\s+", ' ', text)
    text = re.sub(' +', ' ', text)
    text = text.strip()
    return text

# %%
itTicketDF['Description'] = itTicketDF['Description'].apply(clean_data)

# %%
itTicketDF['length']=[len(text) for text in itTicketDF['Description']]
itTicketDF=itTicketDF[itTicketDF['length']>=3]
itTicketDF['Description'] = itTicketDF['Description'].apply(lambda x : " ".join([word for word in x.split() if(len(word)>2)]))

#itTicketDF.drop(['length'],axis=1,inplace= True)
# Out:
# <ipython-input-73-26b8355f76cd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   itTicketDF['Description'] = itTicketDF['Description'].apply(lambda x : " ".join([word for word in x.split() if(len(word)>2)]))

# %%
# translation


germanwordlist = ['bitte','nicht','konto','probleme','berechtigung','defekt','mehr','ausgetauscht','rechner', 'drucker','teilweise','freigegeben','genannten','anmeldeaccount',
                  'besprochen','werden','durchwahl','oben','einrichten','zeitwirtschaft','seit','morgens','beheben','keine','zeitbuchungen','vorhanden','dringend','fehler',
                  'werk','anmelde','auftrag','kein','skannen','freundlichen','werkzeuge,','hartstoffe','maste','schutzw','fertigung','immer','sehr','zugriff','freundliche',
                  'geehrter','souzarft','noch','verbindungsherstellung','meldung','erneuten','glich','proben','beilageproben','beilage','auswerten','sinterleitstand','reparar',
                  'reparo','rechner','koenigsee','entregar','atualiza','declara','programdntya','funcionando','preciso','hitacni','grergtger','zugriffsrechte','teamleiter',
                  'abholen','wegen','weit','absender','wenn','abrechnung']
pattern = '|'.join(germanwordlist)

pattern
# Out:
# 'bitte|nicht|konto|probleme|berechtigung|defekt|mehr|ausgetauscht|rechner|drucker|teilweise|freigegeben|genannten|anmeldeaccount|besprochen|werden|durchwahl|oben|einrichten|zeitwirtschaft|seit|morgens|beheben|keine|zeitbuchungen|vorhanden|dringend|fehler|werk|anmelde|auftrag|kein|skannen|freundlichen|werkzeuge,|hartstoffe|maste|schutzw|fertigung|immer|sehr|zugriff|freundliche|geehrter|souzarft|noch|verbindungsherstellung|meldung|erneuten|glich|proben|beilageproben|beilage|auswerten|sinterleitstand|reparar|reparo|rechner|koenigsee|entregar|atualiza|declara|programdntya|funcionando|preciso|hitacni|grergtger|zugriffsrechte|teamleiter|abholen|wegen|weit|absender|wenn|abrechnung'

# %%
germanDescIndex = itTicketDF[itTicketDF['Description'].str.contains(pattern)].index
germanDescIndex
# Out:
# Int64Index([ 223,  238,  251,  255,  265,  270,  272,  302,  304,  305,
#             ...
#             8414, 8417, 8419, 8420, 8425, 8427, 8436, 8439, 8467, 8499],
#            dtype='int64', length=586)

# %%
# since translation done by googletrans & textblob is giving error while using checking & translating every row, just checking the "Description" for german word like 'bitte'
#!pip install -q googletrans

from googletrans import Translator

def translateIfRequired(x):
    translator = Translator()
    if translator.detect(x).lang != 'en':
        translatedText = translator.translate(x).text
    else:
        translatedText = x
    return translatedText

# %%
for rowId in germanDescIndex:
    print(itTicketDF['Description'][rowId])
    print("\n\n")
# Out:
# hallo ist erneut passiert der hat sich zum wiederholten male aufgeh ngt und mir lediglich einen blauen bildschirm mit weisser schrift sentiert was nnen wir machen
#
#
#
# all have connectivity issue between erp and msd crm due certificate renewal azure websites and that certificate not yet updated erp side issue changes data records accounts sales area data partner functions contacts leads are not being processed from erp worked with msd crm and vice versa all environments prod and dev issue start time troubleshooting steps when tryhdty from customer master team reported the issue that prospect account created erp didn come into msd yet erp team observed that the records are still awaiting acknowledgement status which basically means they are not yet delivered received the target system upon some log analysis and trying identify the root cause between erp basis and msd teams been observed that the issue has started production environment since around est observed the same behavior with azure mfg tool and erp logs other non production environments well you can find error screenshots from erp system the mail chain root cause appears that the certificate for azure webapps have been updated nearing the expiration date but the new certificate not updated erp they are not even aware this change when the production azure webapp company crm mfg toolt azurewebsites net got restarted around this connectivity appears have been broken next steps need the azure webapp certificate chain sent erp basis team that they can update erp system whom can reach out for receiving the certificate details have azure admin house you want open case with microsoft once certificate received maybe can first this system and then upon confirmation that works can apply production and other environments
#
#
#
# bitte passwort mail zur cksetzen bitte neues passwort manager
#
#
#
# probleme mit laufwerk
#
#
#
# hallo netweaver funktioniert nicht mehr bzw kann ich nicht mehr ffnen mit freundlichen best
#
#
#
# neues passwort accountname tgryhu hgygrtui passwort diesen account funktioniert nicht mehr mitarbeiter ist und auf hschicht anwesend
#
#
#
# drucker scanner scanner findet pfad nicht mehr
#
#
#
# tool ist sehr langsadgtym ywqgrbnx jwnsyzbv
#
#
#
# alte abholen
#
#
#
# probleme lan tgeyd
#
#
#
# schulungsraum sprechanlage funktioniert nicht
#
#
#
# konto gespaerrt
#
#
#
# tool aktualisierung alle min uft nicht
#
#
#
# hallo bitte einmal ansehen danke
#
#
#
# labeldrucker druckt nicht mehr
#
#
#
# daten kann nicht heruntergeladen werden die maschine ist stillstand maschine name wam datei werden von udo geschikt datei warden zip und exe format
#
#
#
# erp schulung raum kann beamer nicht verbinden reopened user called again please refer tkt inplant
#
#
#
# probleme mit portal
#
#
#
# setup rechner ewel thrydad thrydad consulting
#
#
#
# bitte konto ewel reaktivieren laptop ein fer konto trhfyd sugajadd ist aktiv bitte ckruf fyi von gesendet dienstag oktober betreff bitte konto ewel reaktivieren laptop ein fer konto rtrhfyd sugajadd ist aktiv bitte ckruf hallo bitte ein tickert help aufmachen die nnen das machen
#
#
#
# probleme mit erpgui
#
#
#
# bildband tauschen drucker
#
#
#
# telefon gigaset professional tel nicht mehr anschluss defekt
#
#
#
# seit gestern uhr fehlen alle zeitdaten daten werden dringend die glichen auswertungen leistungsgrad ben tigt
#
#
#
# probleme mit fixiereinheit
#
#
#
# hallo der drucker scannt keine dokumente ein fehlermeldung zugriff berpr fen folgende ziele fehlgeschlagen hostname kmscan file hostname kmscan der pfad kann nicht gefunden werden der fehler sst sich auch durch mehrmaliges ein und ausschalten nicht beheben mit freundlichen best
#
#
#
# bitte erp freischalten fehlversuche
#
#
#
# der maschine hrt nicht mehr hoch
#
#
#
# tool germany steel ohne funktion ckmelden geht nicht
#
#
#
# hallo kannst einmal nachsehen der mail button ist drucker ist weg danke uwe
#
#
#
# hallo gerade eben ist der computer meinem arbeitsplatz zum wiederholten male ausgestiegen und hat lediglich einen blauen bildschirm mit wei schrift dargestellt bitte schau dir das vor ort mal
#
#
#
# probleme mit lan rechner erodiermaschine
#
#
#
# netzlaufwerke auf auf quattro quattro quattro seit sonntag nicht verbunden
#
#
#
# mit freundlichen best
#
#
#
# hallo help drucker funktioniert nicht mehr richtig etiketten verschieben sich bitte herrn himghtmelreich informieren vielen dank best
#
#
#
# drucker uacyltoe hxgayczeraum knicrhtyt papier
#
#
#
# bitte zugriff auf folgenden pfad einrichten departments hostname programdntyme schichtplaner user freybtrhsdl
#
#
#
# gibt nur eine fehlermeldung aus anmelden netzwerk registrieren der netzwerkeinstellungen nicht alle vorg nge nnen erledigt werden warten sie einen moment
#
#
#
# lable drucker der endkontrolle defense gibt keine etiketten aus
#
#
#
# rechner ngenmessmaschine uacyltoe hxgayczeen
#
#
#
# mit freundlichen best
#
#
#
# mit freundlichen best
#
#
#
# backup rechner lasplant
#
#
#
# tool funktioniert nicht mehr
#
#
#
# zlettel mit freundlichen with best
#
#
#
# collaboration platform nicht verf gbar kein internetzugriff
#
#
#
# tool funktioniert nicht
#
#
#
# hrt nach neustart nicht mehr hoch bzw bricht hrend der hochfahrsequenz den bootvorgang bitte berpr fen danke
#
#
#
# working with the systems almost impossible the processing orders longer possible the moment das arbeiten mit den systemen ist fast nicht glich das abarbeiten von auftr gen ist zur zeit nicht mehr glich
#
#
#
# gehe einmal davon aus das herr aurwddwacher zum ende oktober das unternehmen verl sst bzw ruhestand rente geht prozess der schung des accounts ticketing tool vorlage employee status termination kann unter special instuctrion eine sogenannte delegation angegeben werden somit erh derjenige dem die postfach delegiert wurde zugriff einen bestimmten zeitraum die vorlage wird normalerweise vom vorgesetzten bzw zust ndigen abteilung ausgef llt und sollte mit beiden abgesprochen werden
#
#
#
# open bex analyzer and connect sid try open report xhlg pmm atm product management master the window select values for variables appears available variants data provider set for finance click the system sits and does nothing eventually get microsoft excel not responding error there something wrong with the system there something wrong with settings need pull reports for external auditor rather urgent that get this fixed quickly
#
#
#
# ich will etikettendruck eine zahlen buchstaben drucken als barcode ber word etikettendruck mit der schriftart cosid geht dies nicht das ich mit einer scanpistole lesen kann phone
#
#
#
# bitte user gogtyektdgwo richtig einstellen nach anmeldung fehlen alle netzlaufwerke
#
#
#
# wenn jemand von erhalb anruft dann klingelt das telefon nicht bitte mal nachschauen danke
#
#
#
# guten morgen hkydrfdw der monitor unser ngenmessmaschine ist defekt bitte kurzfristig einen ersatzmonitor bereitstellen danke
#
#
#
# bitte wieder freigeben
#
#
#
# there was change bank details made with ticket this not correctly printing the english forms showing the correct data but the descriptions are german example bankverbindung instead bank address konto nummer instead account number also see that there extra text being printed for the customers bitte beachten sie unsere neue bankverbindung please note our new bank account details only the english version should print the english documents not both german and english
#
#
#
# seit mesz serverprobleme qmsoft nicht anwendbar
#
#
#
# kwddwdw hudfefwe nwfodmhc exurcwkm aramdnty iak urgent help please help check urgent din future please raise such issue our well logistics manager aramdnty johthryugftyson kmvwxdti uaoyhcep iak morning this issue still not solve yet still encounter same issue the net weight higher than gross weight net weight kgs and physical gross weight kgs but erp sid vln shown correct attached for your reference morning need your advice this issue this issue happen since last still not solve yet attached email flow for your reference ksjfye fekfeealleh operation supervisor email aramdnty kmvwxdti uaoyhcep iak hello done have nice day mit freundlichen best
#
#
#
# zugriff auf verzeichnis angefragt folder access requested hostname benutzer user benutzer die position titel user position title verzeichnis folder corpbusinessdev monthly financial review october art des zugriffs type access read only full control
#
#
#
# hallo ersuche alle meine passw rter zur ckzusetzen gesperrt crm erp vpn hello all passwords are locked crm erp vpn mit freundlichen best
#
#
#
# bitte scanner einstellen drucker wurde auf werkseinstellung zur ckgesetzt konica
#
#
#
# fehlermeldung systemfehler andh with potthryzler user identification potzlow tool does not the computer empwa error message system error and
#
#
#
# probleme mit login
#
#
#
# hallo ich kann mich nicht das impact award programdntym einloggen oder mein pass wort zur cksetzen mit freundlichen
#
#
#
# fter defekt industriekontrollmonitor
#
#
#
# probleme mit rechner bleibt ngen
#
#
#
# mein erp passwort funktioniert nicht ich bin gesperrt
#
#
#
# der tool station oder bde germany funktioniert nicht mehr anzeige schreibt festplatten fehler
#
#
#
# fehlermeldung der mail dieser vorgang wurde wegen beschr nkung abgebrochen bitte wenden sie sich den systemadministrator kein hyperlink glich ffnen
#
#
#
# bitte erp account von entsperren
#
#
#
# bitte erp kennwort zur cksetzen
#
#
#
# verbindung zwischen drucker und eemw kann nicht hergestellt werden
#
#
#
# bitte netzteil oder netzstecker evhw wareneingang fen und ggf reparieren sst sich nur nach bewegen des steckers einschalten
#
#
#
# ich chte einen serienbrief erstellen kann aber meine datenquelle excelliste nicht ffnen systemfehler ich bitte hilfe danke
#
#
#
# das folgende word dokument kann nicht mehr bearbeitet werden edksm zeugnis kunden doc der cursor springt ndig auf seite
#
#
#
# hallo bitte jannek ndling zugriff auf den ordner department ausbildung mit freundlichen best
#
#
#
# tool funktioniert teilweise gar nicht
#
#
#
# probleme mit outlook
#
#
#
# rechner optiplex defekt ewew
#
#
#
# hallo bitte lese schreibberechtigung einrichten ist mit besprochen gru betriebsabteilungsleiter technische dienste gesch ftsf hrer managing directors sitz registered office germany registergerirtcht listed the court register germany pers nlich haftende gesellschafterin general partner company company beteiligungs gmbh sitz registered office rth bay registergerirtcht listed the court regster rth von gesendet montag oktober joerg passiep betreff maschinenumstellung bei mir klappt nicht mit freundlichen servicecenter instandhaltung
#
#
#
# hallo zusammen bitte das iphone freischalten mail empfang danke mit freundlichen tel mit freundlichen techn beratung und verkauf company deutschland gmbh max planck stra apple data detectors apple data detectors company deutschland gmbh gesch ftsf hrer rfwlsoej yvtjzkaw harald nnlein herr pinkow diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# hello can not open our branding site receive following error message internet explorer make sure the web address vpn syhtu pozdrsavom mit freundlichem gruss best
#
#
#
# rechner tool ngt sich auf
#
#
#
# rechner infostand defekt probleme mit fter
#
#
#
# probleme mit benutzer erneut nur tempor merdivan
#
#
#
# anmeldefehler lync
#
#
#
# dvi schnittstelle ohne funktion vermutlich grafikkarte defekt
#
#
#
# fehlermeldung systemfehler andh unbekannter fehler
#
#
#
# hello bob geht wieder mal nicht haben wir einen systemfehler bob goes back not even have system failure mit freundlichen best
#
#
#
# bitte sofort lokalen support vor ort schicken fehler analysieren komplette auslieferung des werkes germany steht
#
#
#
# tool und chargenverwaltung geht nicht
#
#
#
# keine ckmeldungen und zuteillisten glich
#
#
#
# serverprobleme soft nicht anwendbar
#
#
#
# telefon defekt
#
#
#
# sitzt neben mir kann seinen account nicht mehr ffnen viele best
#
#
#
# hallo seit einiger zeit werden meinem outlook nicht mehr alle offenen email angezeigt ich muss immer erst auf das blau unterlegte hinweisfeld cken weitere emails sehen nnen das geht aber nur wenn ich eine verbindung zum exchange server habe das nicht immer gegeben ist bitte entsprechend einstellen dass ich alle emails immer lesen kann mit freundlichen best
#
#
#
# workflow meiner gruppe mich nicht sichtbar nicht workcenter emea aerospace gruppe eingetragen
#
#
#
# hello need accses this report hostname departments pubreports file hostname departments pubreports vielen dank mit freundlichen best
#
#
#
# probleme mit lan rechner essa
#
#
#
# pdf dateien gehen nicht auf
#
#
#
# probleme mit portal user gogtyekthyto
#
#
#
# drucker macht willk rlich flecken auf den ausdrucken kopien
#
#
#
# please check computer excel runs slowly analyst planning and reporting company shared services gmbh gesch ftsf hrer diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# probleme mit lan
#
#
#
# keine daten bertragung von auf maschine glich werk plant workcenter ebm maschine eemwx programdntym winprodnc ansprechpartner wunthyder
#
#
#
# nathyresh gayhtjula rwuqydvo anecdfps pradyhtueep yyufs apt run nathyresh request you change the payment method instead for all the employee masters
#
#
#
# helpdesk please provide network connection for alicona edgemaster hone measuring equipment installed this necessary for software updating and also for shatryung relevant information with global team
#
#
#
# hallo zusammen werden bei mir keine wifi verbindungen mehr angezeigt zuhause kann ich mich nicht mehr einw hlen bitte hilfe danke mit freundlichen best
#
#
#
# mehr machen bitte dringend hilfe meine mobile tel
#
#
#
# drucker defekt diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# probleme mit tool fehler beim auftrag abmelden
#
#
#
# laptop defekt
#
#
#
# hallo zusammen der drucker druckt nicht mehr ber die eingabe briefkopf bitte einstellungen korrigieren danke vorab mit freundlichen best
#
#
#
# probleme mit tool
#
#
#
# rden sie bitte einen ordner teams laufwerk rth anlegen name voller zugriff rtgdcoun pngufmvq efodqiuh tpfnzkli rcwpvkyb exgjscql gabryltke sch vielen dank gabryltke sch human resources company shared services gmbh gesch ftsf hrer diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# maschinen ohne funktion bitte fen
#
#
#
# faxen von purchase orders direkt aus der schl seit gestern alle fehl faxing from the purchase orders directly from the has been unsuccessful since yesterday
#
#
#
# rechner erodiermaschine defekt
#
#
#
# hallo bitte nur das passwort appricatehub com impact award zur cksetzen auch die sicherheitsfrage wie hie die erste schule die sie besucht haben nicht korrekt beantwortet werden kann danke
#
#
#
# maus defekt
#
#
#
# probleme mit cad
#
#
#
# hallo liebe kollegen kolleginnen ich kann skype nicht starten kommt immer diese fehlermeldung zlettel mit freundlichen best
#
#
#
# nwfodmhc exurcwkm dan die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird importance high dear all please activate new iphone company owned device
#
#
#
# nwfodmhc exurcwkm geoyhtrge wuryhtudack trurthyuft ticket drucker hello help team pls enter ticket regarding defect scanner printer plant manager controlling local already working that with external supplier just make sure all work tracked thx marfhtyio mit freundlichen best
#
#
#
# handscanner evhw bei funktioniert nach tausch immer noch nicht bitte fen und bei bedarf nochmals tauschen
#
#
#
# momitor defekt
#
#
#
# hallo bitte tool unter infos einen neuen pfad anlegen unter impact award ein neues verzeichnis anlegen als bezeichnung bitte erp verwenden die dateien zum visualisieren befinden sich auf handb cher erp file hostname info handb cher erp reason have created some traiyctrhbkm plvnuxmrterial for our shopflor workers for our new erp system for creating breakdown notifications they will have chance look into this traiyctrhbkm plvnuxmrterial when they want any notification fjaqbgnld yukdzwxs people because still started with erp and our old system was part tool called azm mit freundlichen best
#
#
#
# hallo leider repliziert mein laptop firmennetz nur rudiment iphone bekomme ich die neusten emails das problem haben auch andere kollegen hier standort mit freundlichen best
#
#
#
# barcode scanner defekt paternoster
#
#
#
# rollomatic alfa set messger ssen die einstellungen laut anleitung berpr werden
#
#
#
# bitte passwort benutzer franhtyuj zur cksetzten wurde mehrfach falsch eingegeben danke
#
#
#
# erp schulung raum kann beamer nicht verbinden
#
#
#
# just tried change password via passwordmanager and locked totally would you please kind and unlock again that can change again mit freundlichen analyst logistics company shared services gmbh gesch ftsf hrer diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# monitor defekt fuer neu bau stock
#
#
#
# ich kann meinen vpn nicht ffnen
#
#
#
# probleme mit laser
#
#
#
# probleme mit lasplant
#
#
#
# wenn ich outlook aufrufe will der rechner gleichzeitig sich auch noch mit collaboration platform verbinden das lautet mit ihrem gesch fts oder schulkonto anmelden wenn ich meine emailadresse und mein password eingebe passiert aber nichts das ndige einblenden ist sehr rend bitte abhilfe meine telefonnummer ist
#
#
#
# abholen alte equipment cad monitor
#
#
#
# probleme mit die druckerwarteschlange wird zurzeit nicht ausgef hrt
#
#
#
# skype wird nicht vom browser geladen auch nicht nach langer wartezeit
#
#
#
# die systeme tool chargenverwaltung pdv laufen absolut schlecht man kann mit ihnen nicht wirklich arbeiten
#
#
#
# email screen shot error duane said remember seeing similar error during uacyltoe hxgayczeing that resolved which had with the customer master think had with uacyltoe hxgaycze request and using the actual customer rather than the requester the tandd customer this npr for quote and not tandd order
#
#
#
# nwfodmhc exurcwkm die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird help desk please take new iphone out quarantine
#
#
#
# bitte schalten sie meine passw rter frei plase unlook password chrithysgd mit freundlichen best
#
#
#
# empw defekt code xed blue screen
#
#
#
# install drucker ewew
#
#
#
# install drucker ewew
#
#
#
# install drucker oziflwma nhgvmqdl
#
#
#
# aktuell nnen keine ckmeldungen tool eingegeben werden fehler laufzeitfehler
#
#
#
# automatische datenaufbereitung geht nicht
#
#
#
# purchasing online katalog technischer handel funkioniert nicht
#
#
#
# bitte passwort und acount freischalten mit freundlichen best
#
#
#
# never received access tghkris wickhamtf person folder the network drive did get access her collaboration platform drive but not her network folder know her network folder where she saved lot information really need have access this folder access her documents also not sure why the communications receiving regarding her collaboration platform collaboration platform are german die endg ltige schung des collaboration platform for business von gflewxmn qnxhoryg ist tagen geplant sie haben immer noch zeit wichtige dokumente einen anderen speicherort kopieren nach tagen wird das collaboration platform for business von gflewxmn qnxhoryg endg ltig gel scht wechseln sie zum collaboration platform for business von gflewxmn qnxhoryg unter
#
#
#
# probleme mit com port maschine hrmann
#
#
#
# bitte schalten sie meine passw rter frei mit freundlichen best
#
#
#
# anlagen der hochdrucksinteranlage hip startet nicht
#
#
#
# probleme mit gehaltsnachweis drucken
#
#
#
# probleme mit wlan laptop
#
#
#
# probleme mit
#
#
#
# hallo kannst mal bei uns labor vorbei schauen ist der monitor vom rfa analyseger defekt ist der ansprechpartner
#
#
#
# kein datenabgleich zwischen tool und erp germany
#
#
#
# ich habe meinem nur zugriff auf die interne festplatte drucken funktioniert aber kein zugriff auf die drucker server
#
#
#
# hallo port ewew port liefert keine richtige bitte fen
#
#
#
# halo der drucker bereitet problem mit dem druck bitte die einstellungen berpr fen danke uwe
#
#
#
# probleme mit vpn
#
#
#
# probleme mit portal franjuz urbghty
#
#
#
# hallo kollegen bitte mal fen warum der kollege diehm diese frage gestellt bekommt auf nein klickt and sich dann nicht einloggen kann dank and gru cid hardcopy cid
#
#
#
# probleme mit alicona nach update
#
#
#
# sehr geehrte kollegen ich kann den netweaver business clint nicht ffnen wenn ich auf die entsprechende app cke ber vpn bereits verbunden dann kommt folgender hinweis bitte ihre unterst tzung mit freundlichen best
#
#
#
# tool ewew funktioniert nicht
#
#
#
# hallo mein zeigt blaue seite mit vielen wei buchstaben typ optiplex bitte helfen best
#
#
#
# while updating existing product management master key figures dierppear and shown columns also columns dierppear and download distrtgoyed last month have had the same issue anybody made changes the product management master pallutyr pande corrected back maybe you can involve her again are very bussy with month end data and immediately need the correct settings they have been before sample before refresh best
#
#
#
# hallo das ffnen von pdf files aus engineering tool dauert heute extrem lange manchmal erscheint auch diese meldung ohne dass das file ffnet wird mit freundlichen best
#
#
#
# probleme mit
#
#
#
# sinic allgemeiner fehler odbc vmsliazh ltksxmyv driver abfragetimeout
#
#
#
# hallo unser kopierer schulungsraum ist auch defekt minolta kannst bitte mal nachschauen
#
#
#
# zugriff auf verzeichnis angefragt folder access requested benutzer user ahujajtyhur benutzer die position titel user position title executive sales admin verzeichnis folder scan art des zugriffs type access read only full control full name des vorgesetzten manager name please help assign scanner system best
#
#
#
# hallo kollegen meinem outlook kommt ein feld dass ein app problem vorhanden ist was ist tun mit freundlichen best
#
#
#
# kothyherr has not received any mail from ethics since long time thinks should have received least mails during this period that why unable the course insists ethics look into hallo kollegen ich sollte eigentlich meine ethics vorg nge abarbeiten dazu habe ich jedoch keinerlei erinnerungsinformationen bekommen noch einen link wie ich das portal komme deswegen habe ich versucht ber hub das portal kommen dazu habe ich auf login gedr ckt dann auf den button deutsch dann kommt jedoch keine offene session was ist tun mit freundlichen best
#
#
#
# kann sich nicht anmelden
#
#
#
# mit freundlichem gru kind
#
#
#
# bei drucker keine ausgabe der druckauftr aus erp hrp druck aus word excel funktioniert drucker wurde bereits ausgeschaltet und neu gestartet ohne erfolg please complete all required questions below not will returned back the gsc requester provide required information gsc review ticket not able resolve then please assign appropriate group per your printer problem assignment flowchart printer name make model detailed description the problem type documents not printing email excel word etc inwarehouse tool delivery note production order etc what system application being used time the problem windows erp kls not printing all does respond ping command the network and has power cycle the printer been completed erp system which system sid sid hrp plm erp printer problem can the erp output rerouted another erp printer temporarily what printer can rerouted too document not printing correctly please scan copy the document and attach the ticketing tool ticket
#
#
#
# someone the service center was able successfully add partner existing customer master account sid set that only the users assigned the cust mast partner func role would have add edit delete access this partner function here summary what happened per lillanna was using sid ecc what strange that the system gave him warning that not allowed add partner function could not even save changes until cleared the field but seems the system added the partner function anyway when saved the account the account was and added partner
#
#
#
# hallo reisekostenabrechnung erp leider nicht glich siehe fehlermeldung unten mit freundlichen best
#
#
#
# anmelden bei outlook seit passwort ndern nicht glich tel
#
#
#
# probleme mit drucken vermessungsmaschine
#
#
#
# drucker druckt mit bis std verz gerung wird von eemw aus gedruckt messecke printer name make model detailed description the problem printer takes too long time print error error turn off then the printer restarted couple times does not help printer can not pinged see attachment looks like non existing printer type documents not printing email excel word etc data from access datenbank excel inwarehouse tool delivery note production order etc what system application being used time the problem windows erp kls windows
#
#
#
# nyifqpmv kfirxjag travel expense manager hello transaktion also doesn work for personal and mit freundlichen programdnty engineering europe gesch ftsf hrer von gesendet freitag nyifqpmv kfirxjag betreff travel expense manager hello travel expense manager doesn work mit freundlichen programdnty engineering europe
#
#
#
# probleme mit skype und outlook user dardabthyr
#
#
#
# probleme mit skype und outlook dardabthyr
#
#
#
# kannst bitte noch mal usb sticks besorgen bei uns ist wieder einer kaputt gegangen
#
#
#
# unser kopierer laserjet zeigt fehlermeldung transfereinheit fehlt
#
#
#
# telefon mit der nummer ist defekt sinterei germany bitte reparieren
#
#
#
# probleme mit vpn
#
#
#
# probleme mit companyguest
#
#
#
# probleme mit drucker local
#
#
#
# ich ben tige hilfe bei der passwort nderung und bei skype mikrophone zuschaltung ich bei skype meetings zwar andere ren kann diese mich aber nicht ren nnen
#
#
#
# rechner evhw funktioniert outlook nicht mehr
#
#
#
# nwfodmhc exurcwkm amar die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird importance high please usa access for that company owned device user grbhybrdg thanking you anticipation oqlcdvwi pulcqkzo von microsoft outlook gesendet mittwoch betreff die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird der zugriff von ihrem mobilen ger auf inhalte ber exchange activesync ist vorr bergehend blockiert quarant gestellt ist sie ssen keine aktion durchf hren der inhalt wird automatisch heruntergeladen sobald der zugriff vom administrator gew hrt wird please ignore the above paragraph cannot change delete special note jan the microsoft outlook app for ios and android released yesterday not currently approved software for accessing company mail until uacyltoe hxgayczeed and approved please consider using one the other the embedded mail software your mobile device the browser your mobile device the microsoft owa app published for your mobile device platform beginning employees with supervisor approval use personally owned mobile devices access outlook email company moving forward and providing the opportstorage product for our employees use specified personally owned devices allow for productivity improvement and enable work life balance this addition the policy for company owned devices currently approved handheld devices can found this policy wireless mobility technical document the above policy will updated other devices are approved for use you own approved device and would like take advantage this opportstorage product you can submit ticketing tool ticket the global support center gsc personally owned device you need attach the agreement form found the wireless mobility standard procedure this agreement must signed you and your next level supervisor and provided the gsc prior ticket being entered you can attach the signed form the ticket send the signed form the gsc and they will attach any ticket without the signed form will cancelled you have weeks process and submit the form before your device will denied deleted from quarantine wireless mobility standard procedure informationen ihrem mobilen ger ger temodell iphonec ger tetyp iphone ger fvqfjrgjrjbkdgus ger tebetriebssystem ios sartlgeo lhqksbdxa ger tebenutzer agent apple iphonec ger imei exchange activesync version ger tezugriffsstatus quarantined grund ger tezugriffsstatus global gesendet
#
#
#
# probleme mit
#
#
#
# probleme mit portal
#
#
#
# probleme mit portal
#
#
#
# meeting was scheduled former employee organizer panjkytr mehrota nextgen kentip mfg details panjkytr mehrotra panjkytr mehrotra ohljvzpn phwdxqev ksvlowjd ptyzxscl aditya choragudi gotbumak ymdqokfp ruy frota estaxpnz mqhrvjkd ynlqrebs hwfoqjdu doug harman frmyejbx weclfnhx raouf benamor lpnzjimdghtyy lwguyibh nqepkugo knqmscrw sdtoezjb nextgen kentip mfg when occurs every effective until from utc eastern time and canada where mccoy
#
#
#
# lese und schreibberechtigung hostname produktion
#
#
#
# hello help the zlz agreement shown demand but the for the production plant the zlz agreement not shown demand maybe problem with the material type mit freundlichen best
#
#
#
# printer name make model laser jet detailed description the problem druckauftrag wir nicht ausgef hrt type documents not printing email excel word etc what system application being used time the problem windows erp kls not printing all does respond ping command the network and has power cycle the printer been completed erp system which system sid sid hrp plm erp printer problem can the erp output rerouted another erp printer temporarily what printer can rerouted too document not printing correctly please scan copy the document and attach the ticketing tool ticket
#
#
#
# eemw einrichten damit der barcode angezeigt und man ihm drucken kann ebs dicker
#
#
#
# hello need viewer computer check step files mit freundlichen ssen with best
#
#
#
# drucker auslieferbereich immer den gleichen lieferschein mal danach wird erst der richtige ausgedruckt erp problem
#
#
#
# mit freundlichem gru ulrike mann custom solutions engineering europe drillingandcountersinking company shared services gmbh wehlauer strasse rth www company com company shared services gmbh gesch ftsf hrer sitz der gesellschaft rth bay registergerirtcht rth bay hrb diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# hallo frau rie wird dienstag oktober wieder ihre arbeit beginnen bitte passwort neu vergeben frau rie wird voraussichtlich von bis uhr erreichbar sein mit freundlichen best
#
#
#
# system sid sid sid sid hrp other enter user user having the issue reisenkostenabrechnung nicht glich viele falsche anmeldungen bitte passwort zur setzen danke transaction code the user needs was working with describe the issue you are getting not authorized message recreate the condition then nsu and attach result the ticketing tool ticket provide access the same this other user
#
#
#
# ich kann seit woche meine suche outlook nicht verwenden der hinweis ihre elemente werden zurzeit von outlook indiziert erscheint habe auch meinen mit ffnetem outlook bers wochenende laufen lassen doch bisher immer das gleiche aktuell ssen noch elemente indiziert werden gestern waren elemente ich habe somit massive probleme ich mails von vor einem jahr bis jetzt mit der suchfunkton nicht finden kann
#
#
#
# rechner ewew bluescreen
#
#
#
# probleme mit fehler
#
#
#
# rechner ewew sehr langsam
#
#
#
# dear still some issues with the tracker even with your message collaboration tool etc jertyur can make ticket and contact you some other person they cannot enter any projects please let know mit freundlichen best
#
#
#
# probleme mit druecker fehlermeldung transport einheit fehlt oder motor fehler aufgetreten das ist eine leasing druecker
#
#
#
# hello college anrgtdy bofffgtyin came germany germany fort work and needs connect lan could you please send him password for guest lan connetction anrgtdy bofffgtyin technical programdntyme manager aerospace and defence mit freundlichen best
#
#
#
# good day can you please advise whether crm going through updates the moment there are number issues concerning the moment cannot access crm all yesterday could not enter new customer accounts drop down boxes were not fully loading and thus could only see one two items select from the team here australia advised that lately that they have had contact customer master numerous occasions there are certain entries crm new customer accounts that are not transferring erp like sales reps carriers etc were advised our finance department that they believed were aware such problems above kind
#
#
#
# hallo ich archiviere meine mails einer ordnerstruktur leider finde ich immer wieder ordner die tzlich keinen inhalt mehr haben was uft hier falsch gru achim sales manager sales germany company deutschland gmbh gesch ftsf hrer rfwlsoej yvtjzkaw diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# hallo liebe kollegen warum habe ich diese mail bekommen hat jemand etwas modifiziert meine mail postfach zlettel mit freundlichen best
#
#
#
# disable private address fields new and edit buttons employee master crm
#
#
#
# kann von dieser adresse nichts empfangen oder gesendet werden
#
#
#
# dear please help need approve this but cannot the following expense report has been submitted for your approval personnel expense report start date end date total costs usd reimbursement amount usd review this expense report full please log into your universal worklist manager self service get this message mit freundlichen best
#
#
#
# support rechner messvorrichtung
#
#
#
# rechner funktioniert nicht
#
#
#
# rechner viotto funktioniert nicht
#
#
#
# erp netweaver portal ist nicht mehr glich unter dem paramdntyeter feinnavigation die bestell bersicht aufzurufen siehe angef gte screenshots
#
#
#
# rechner ewewx olympus kein zugriff auf hostname tool glich
#
#
#
# install tool und bls rechner olympus
#
#
#
# hallo bitte schreib und leseberechtigung user maerza auf den ordner staebefertigung leitung einrichten danke
#
#
#
# nyifqpmv kfirxjag unterhaltung mit nyifqpmv kfirxjag hello ramdntyassthywamy sebfghkasthian asked send you the below attached screen shots mit freundlichen best
#
#
#
# drucker von cvd einrichten der
#
#
#
# probleme mit collaboration platform infopath
#
#
#
# bitte netzwerkverbindung rechner vhw herstellen alicona messraum halle
#
#
#
# anmeldung bei account helftgyldt nicht glich fehlermeldung das angesprochene konto ist momentan gesperrt und kann nicht die anmeldung verwendet werden
#
#
#
# anmeldung bei account jncvkrzm thjquiyl nicht glich fehlermeldung das angesprochene konto ist momentan gesperrt und kann nicht die anmeldung verwendet werden
#
#
#
# erp passwort mal verkehrt eingegeben bitte erp account freischalten
#
#
#
# aufl sung bildschirm von eemw sehr schlecht nderungen werden nicht bernommen
#
#
#
# bluetooth headset bekommt keine verbindung mit
#
#
#
# probleme mit erpgui
#
#
#
# konto gesperrt handy wlan authentifizierungsproblem
#
#
#
# access point defekt
#
#
#
# probleme mit skype
#
#
#
# hello have problem with tool can not get the transfer times our employees the downloaded file empty without this datas not possible calculate the productivity our plants germany mit freundlichen ssen with kind
#
#
#
# bitte telefon tauschen
#
#
#
# bitte erstellen sie mir eine liste ber alle berechtigungen bzw zugriffe von cvltebaj yzmcfxah rostuhhwr
#
#
#
# ich ben tige folgende personen aus germany die angegeben berechtigung den ordner hostname teams schlammversand sludgeshipping nur leseberechtigung hoscgthke metallurgie langhdte schneidk rper hbyoyer befertigung dahytrda distribution retzkowski controlling chsbhuo controlling
#
#
#
# hello please activate new company owned samsung galaxy for office access ger temodell ger tetyp samsungsmgf ger seceffa ger tebetriebssystem android ger tebenutzer agent android samsung ger imei exchange activesync version ger tezugriffsstatus quarantined grund ger tezugriffsstatus global you can remove the existing samsung galaxy device from account but not remove any other devices that have access account
#
#
#
# drucker defekt
#
#
#
# die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird
#
#
#
# monitor der endkontrolle defekt
#
#
#
# hallo ich und brauchen eine neue anst ndige maus hre sch wenn sie kurzfristig uns vorbei bringen nnuacyltoe hxgaycze
#
#
#
# hallo ich und brauchen eine neue anst ndige maus hre sch wenn sie kurzfristig uns vorbei bringen nnuacyltoe hxgaycze
#
#
#
# probleme mit symantec konferenzraum
#
#
#
# fehlermeldung
#
#
#
# ebusiness service jfwvuzdn xackgvmd nwfodmhc exurcwkm radgthika order products online problem hello the issue that your userid locked erp sid and erp sid you need the password management tool password manager and first select the option unlock accounts after that select the option change password once that completed successfully you should logon distributor tool with that new password mit freundlichem gru kind
#
#
#
# lean tracker ffnet nicht fehlermeldung erscheint
#
#
#
# gigaset mit der durchwahl akku nicht mehr nger wie tag kann display nicht mehr erkennen clip defekt
#
#
#
# drucker druckt nicht mehr irgend ein fehler papiereinzug nach anweisung fehlermeldung nachgeschaut und nichts gefunden
#
#
#
# erp drucker druckt nicht sauber seiten wedgrtyh ahsnwtey
#
#
#
# durch den zugriff per iphone auf den mail account das gesamte konto gesperrt wurde muss der account auf dem iphone gel scht und neu anlegt werden
#
#
#
# vermutlich hat der zugriff mit dem iphone das konto wieder gesperrt passwort nochmals zur ckgestzt werden
#
#
#
# bitte laufwerk germany unter berechnungsprogramdntym die sicherungsdatei stp vom datum wiederherstellen ben tigen wir produktionsinfos raus geben
#
#
#
# help for the post code the shipping label from kis below but the correct post code should cec confirms same customer master copy the screens below can you check what caused the wrong post code the label
#
#
#
# hallo folgende mitarbeiter ben tigen zugriff auf unten stehen verlauf skv alicona mitarbeiter kudhnyuhnm kesrgtyu rockehsty koiergyvh und simekdty vergleichsmitarbeiter beckshtywsnh beckshtyw
#
#
#
# drucker geht nicht mehr trotz mehrere druckauftr kein anderer drucker instaliert bitte drucker auch instalieren
#
#
#
# bitte freigabe von skv alicona
#
#
#
# bitte freigabe skv alicona einrichten
#
#
#
# bitte freigabe skv alicona einrichten
#
#
#
# bitte die drucker umstellen und konfigurieren
#
#
#
# erp net weaver funktioniert nicht empw
#
#
#
# passwort ist abgelaufen bitte reset einleiten auch das iphone
#
#
#
# name mehrugshy language browser microsoft internet explorer customer number telephone summary not able log into vpn when trying open new session going the your session finished page
#
#
#
# kein zugriff auf zeiterfassung und sonstiges netzwerk
#
#
#
# maus funktioniert nicht mehr richtig bitte ersetzen
#
#
#
# keine anmeldung auf skype glich
#
#
#
# bitte toner fen und ersetzen freundlicher gru best
#
#
#
# bitte guest wifi fuer gastronomie fuer eine jahr einrichten
#
#
#
# hello receive the following error message when try open finance app plant monthly book could you please check mit freundlichen ssen kind
#
#
#
# der mitarbeiter schrenfgker heinrifgtch ben tigt zugriff pulverleitstand lesen and eintragen
#
#
#
# eeml wlan sst sich nicht per knopfdruck aktivieren ist informiert bitte haende hrrn pries
#
#
#
# source system name whqsm reference company com user name location dmz sms status field sales user yes dsw event log see below the ctoc has received least occurrences vid possible magento mage adminhtml block widget gridgetcsvfile sql injection attempt inbound cve alerts from your isensor device isensplant company com for traffic not blocked sourcing from port tcp dallas usa destined port tcp usa usa that occurred this indicates that the external host and possibly other sources are attempting discover your public facing servers including vulnerable the magento mage adminhtml block widget grid getcsvfile sql injection vulnerability described cve this ticket will effectively serve master ticket for any related alerts until receive feedback from you how handle these events going forward please let know either corresponding via this ticket and delegating the ticket back the ctoc calling have number options available for the handling future alerts such this one autoresolve these alerts directly the portal explicit notification and events will available for reporting purposes the portal this most likely the best choice you are not running the application being targeted ticket only escalation via medium priority ticket phone call for each unique source address for these alerts this generate relatively large volume incident tickets full escalation via high priority ticket and phone call for each unique source address would not recommend options and since the exploit code the wild and merely identifying the sources the attack not very useful and can always run reports the portal identify list attackers instead would recommend auditing your environment for vulnerable systems and updating them necessary once you have completed this you could with option suppress alerting these events sincerely ctoc technical details vulnerability exists magento due insufficient input validation within the mage adminhtml block widget grid getcsvfile function remote attacker could exploit this vulnerability conduct sql injection attacks vulnerable systems magento eusa platform vulnerability exists magento commstorage product edition versions through version versions versions through versions and versions and and magento enterprise edition versions prior due insufficient input validation user controllable supplied via the popularity field expr paramdntyeter when the popularity from popularity paramdntyeter set not properly sanitized for illegal malicious content the mage adminhtml block widget grid getcsvfile function prior being stored fieldname variable and used sql query remote administrators could leverage this issue conduct sql injection attacks injectncqulao qauighdplicious sql code into affected input successful exploitation permit attacker manipulate sql queries and execute arbitrary sql commands the underlying database references event data related events event event summary vid possible magento mage adminhtml block widget gridgetcsvfile sql injection attempt inbound occurrence count event count host and connection information source source port source geolocation dallas usa destination destination port destination geolocation usa usa connection directionality incoming protocol tcp http method post host www company full url path admin cms wysiwyg directive index device information device device name isensplant company com log time utc action not blocked vendor eventid cvss score vendor priority vendor version scwx event processing information sherlock rule sle inspector event ontology event type agent event detail vid possible magento mage adminhtml block widget gridgetcsvfile sql injection attempt inbound classification none priority action accept passive impact flag impact blocked vlan mpls label pad sensor event time src dst sport itype dport icode pro tcp ttl tos iplen dgmlen seq ack xbedac win tcplen tcp options nop nop pcap http uri admin cms wysiwyg directive index http hostname www company security ascii packet pcap ascii pcap ascii hex pack ...
#
#
#
# ...
#
#
#
# probleme mit lan ewew
#
#
#
# probleme mit lan ewew
#
#
#
# wireless access point funktioniert nicht
#
#
#
# fehlermeldung failed connect server kollegen der presserei ist die nummer aber richtig und der wurde auch nicht ausgetauscht oder erneuert danke
#
#
#
# bitte die maschine precimat wieder freischalten unter azm
#
#
#
# hallo die server verbindung lic ist gest kann nicht erp gebucht werden nnen sie sich des problems annehmen danke mit freundlichen best
#
#
#
# hello need your help connecting with erp not possible receive this error message mit freundlichen best
#
#
#
# please see error message from erp mit freundlichen best
#
#
#
# bei frau dde ist der drucker nicht wenn sie etwas scannt ist der scan sie kann nichts ausdrucken der drucker springt zwar aber kommt nichts raus
#
#
#
# probleme mit office girnda
#
#
#
# alte equipment abholen
#
#
#
# leider kann ich mich nicht meinem rechner anmelden fehlermeldung die verstrauensstellung zwischen dieser arbeitsstation und der prim ren dom konnte nicht hergestellt werden
#
#
#
# engineering drawing tool keine zeichnungsrahmen kommt die meldung aus dem anhang
#
#
#
# tool lassen sich keine azm meldungen eintragen tool azm messages can not registered
#
#
#
# verehrte damen und herren meinem festnetztelefon ist seit geraumer zeit die anzeige display nur noch unvollst ndig erkennbar mehrere waagerechte linien machen die anzeige unlesbar meine telefonnummer lautet bitte abhilfe mit freundlichem gru quality assurance
#
#
#
# tastatur und defekt bitte austauschen einzelne tasten funktionieren nicht mehr
#
#
#
# mail nwfodmhc exurcwkm amar company email accounts dear support team get company mail adress today for the rpo project betwenn company and ibm was mis typing last name zihrtyud can you change this please many
#
#
#
# probleme mit lan
#
#
#
# probleme mit ffnen von dokumenten intranet mit internet explorer
#
#
#
# danke diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# hallo herr busse rden sie dies bitte via ticket die schicken bzw mit freundlichen best
#
#
#
# mit freundlichen with best
#
#
#
# team can not generate intercompany for delivery note the following error message appears can you please have look mit freundlichen grugermany best
#
#
#
# leider ist das feld von abhanden gekommen danke viele mit freundlichen best
#
#
#
# probleme mit tool
#
#
#
# hallo kann auf rechner outlook nicht starten und crm synchronisiert stundenlang dadurch werden auch andere dinge geblockt engineering tool bitte hilfe sitze rechner mit freundlichen ssen uwe schr technische beratung und verkauf mobil tel company deutschland gmbh max planck stra germany www company com company deutschland gmbh gesch ftsf hrer rfwlsoej yvtjzkaw harald nnlein sitz der gesellschaft germany hgermany registergerirtcht bad homburg hgermany hrb diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung company posts select the following link view the disclaimer alternate language
#
#
#
# programdntyme lassen sich teilweise nicht ffnen mal nach der festplatte schauen bitte erledigung durch himghtmelreich tool rep
#
#
#
# hallo frthdyui passwort nderung der hat nicht geklappt bitte deine hilfe lieben dank voraus gru petrghada
#
#
#
# collaboration platform online not opening error diese seite kann nicht angezeigt warden
#
#
#
# hallo help office produkte zeigen folgende fehlermeldung gru
#
#
#
# aenderungsantrag kann nicht geloescht werden
#
#
#
# probleme mit purchasing
#
#
#
# authorisation error outlook nicht lizeciertes produkt
#
#
#
# moin kannst bitte das passwort freischalten benutzer wurde das passwort gesperrt bitte das passwort auf welcome setzen
#
#
#
# probleme mit datenbank tool
#
#
#
# ticketing tool for user email available see picture mit freundlichen best
#
#
#
# von gesendet donnerstag nwfodmhc exurcwkm betreff ewkw ewkw funktioniert nicht sst sich anschalten danach ist kein arbeiten glich auch mit anderer tastatur versucht keine nderung mit freundlichen grinding service germany
#
#
#
# hallo ist glich das ich office von englisch auf deutsch umstelle wenn finde ich diese einstellung wenn ich die videos von lets talk deutsch ansehen chte und diese ber den link der email anklicke sagt mir office video isn available office video not enabled your organization for you hier ein link vielen dank ihre hilfe
#
#
#
# could you please check what wrong with customer master can create delivery because there are incomplete log pricing error mandatory condition mwst missing check with pricing department and mwst defined for this customer corretly there should tax like for turkey tax free trade zone because customer from azerbaijan maybe has added some condition for this country also have ship the tools today because new order form new distributor with big potential priority
#
#
#
# durchwahl mobilteil gigaset lautsprecher mikrofon kratzen bzw setzten zeitweise aus
#
#
#
# pradtheyp nathyresh with effect from tuesday propose make all vendor payments through bank order facilitate this process you are requested make the following changes the vendor master for all domestic vendors list enclosed house bank changed from itelephony softwarei bank bank amerirtca method payments should and mail address updated correspondence internet once the changes are made please confirm that can initiate the first payment vendors through bank
#
#
#
# auftr funktionieren auftr lassen sich nicht bearbeiten beim ausliefern
#
#
#
# erp pthsqroz moedyanvess error message object notification business operation not entered your user master
#
#
#
# bitte weiterleiten nachdem das alicona messger umgestellt wurde muss der sdnemlwy dsbmgonk aufgebaut werden apl vor juchaomy gaxrulwo abstechprogramdntym soll termin bis mitarbeiterin kommt zur
#
#
#
# bitte weiterleiten alicona messger muss von abstechprogramdntym halle ehem ventilst kontrolle umgestellt werden soll termin
#
#
#
# nwfodmhc exurcwkm sab skype sst sich nicht starten bitte unterst tzung freundliche gruesse kind
#
#
#
# hallo gibt anscheinend probleme bei der bertragung von stempelzeiten tool erp bei stelligen personalnummern siehe unten freundliche von gesendet donnerstag juli betreff leihmitarbeiter lochthowe andre hallo zusammen seit dem stempelt herr lochthowe mit seiner karte tool seit dem zeitpunkt werden die daten nicht erp bertragen hier stimmt etwas nicht mit der karten oder der stammnummer wir haben hier den ersten mitarbeiter mit einer achtstelligen stammnummer kann daran liegen bitte mal fen mit freundlichen best
#
#
#
# von pradyhtueep yyufs gesendet nathyresh gayhtjula erp fico ebusaar munnangi iszaguwe bdfzamjs joacrhfz ctrbjusz maryhtutina bauuyternfeyt betreff zahllauf nicht ausgef hrt international payments rejected jartnine are looking into the development changes which were implemented recently will get back you tomorrow sorry for any inconvenience
#
#
#
# wegen ein sicherheitsupdate sind keine netzwerkverbindung moeglich fehlermeldung keine netzwerk verbinung
#
#
#
# kann keine auftrag gedruckt werden ziehe fehler
#
#
#
# zlettel mit freundlichen best
#
#
#
# error verbindung system production order interface app mit destination production order interface vendor connc fehlerhaft fehler beim ffnen einer rfc verbindung cpic call
#
#
#
# hello path the folder hostname departments lean lean projekte lean projekte geplant file hostname departments lean lean projekte lean projekte geplant mit freundlichen best
#
#
#
# wir haben hier koenigsee probleme mit dem druck aus erp kommt ein production order interface app fehler
#
#
#
# wird nichts mehr ausgedruckt fehlermeldung mit freundlichen best
#
#
#
# probleme mit erpgui
#
#
#
# barcode scanner defekt
#
#
#
# zugriff auf verzeichnis angefragt folder access requested benutzer user karagtfma benutzer die position titel user position title manager commodities amerirtcas verzeichnis folder hostname all items under purchasing art des zugriffs type access read only full control full control name des vorgesetzten manager name
#
#
#
# tool funktioniert nicht meldung unbekannten fehler system distributor tool fehler
#
#
#
# mmaster sales org extensions created oprbatch are creating errors matgrp and material statistics examples extended which had correct this morning sales org sales org had today that were blank and needed corrected manually extended these the system doesn allow save with blank need oprbatch populate these fields mmaster sales org extensions created oprbatch are creating errors matgrp and material statistics examples extended which had correct this morning sales org sales org had today that were blank and needed corrected manually extended these the system doesn allow save with blank need oprbatch populate these fields
#
#
#
# install bit version von office rohlings fertigung
#
#
#
# hallo help team ich habe das problem dass wenn ich nach versendeten emails suche ber die suche nach namen kommt folgende fehlermeldung kommen immer nur vorschl bis zum bitte fen und ckinfo vielen dank mit freundlichen kind
#
#
#
# das passwort wurde meinerseits falsch eingegeben bitte passwort zur cksetzen engineering tool und erp danke
#
#
#
# please restore from westes hostname file hostname betriebliche regelungen und anlage bonus docx danke viele mit freundlichen best
#
#
#
# mensagem erro infelizmente outlook encontrou erro que est impedindo funcionar corretamente como resultado outlook dever ser fechado gostaria que fiz ssemos reparo agora com bot que reparar agora fechar ajuda
#
#
#
# usar microsoft update atualizar adobe acrobat adobe flash java revisar grupos revisar atualizar revisar patching antivirus revisar erp client executar check disk defrag scan atualizar drivers dell verificar atualiza nova vers pacote office uacyltoe hxgayczear acessos itau caixa hsbc uacyltoe hxgayczear abertura plaghynilhas ita
#
#
#
# bitte austauschen
#
#
#
# mit freundlichen with kind
#
#
#
# hallo zusammen siehe nachstehenden email schriftverkehr bitte scghhnellstens beheben danke mit freundlichen best
#
#
#
# bitte wzs wza bios ndern das nach netz reset der rechner selbstst ndig startet bitte erledigung durch himghtmelreich
#
#
#
# probleme mit rechner ewew defekte sektoren
#
#
#
# hello altogether have problems with our tool please open zuteillisten plant hartbearbeitung kantenverrunden sammelarbpl then you see this window the past when doubleklick eps could see new window our point measurement for this inserts but now this function out service mit freundlichen best
#
#
#
# hello altogether have problems with our tool please open zuteillisten plant hartbearbeitung kantenverrunden sammelarbpl then you see this window the past when doubleklick eps could see new window our point measurement for this inserts but now this function out service mit freundlichen best
#
#
#
# team anbei ein investmentantrag einen neuen rechner laptop mit freundlichen best
#
#
#
# stepfhryhan needs access below collaboration platform links urlaubsplanung file efdl users linnes collaboration platform company inc teamordner linnemann urlaubsplanung file efdl users linnes collaboration platform company inc teamordner linnemann ene allgemeines file efdl users linnes collaboration platform company inc teamordner linnemann allgemeines berirtchtswesen gebiet nord file efdl users linnes collaboration platform company inc teamordner linnemann berirtchtswesen gebiet nord crm teamordner file efdl users linnes collaboration platform company inc teamordner linnemann crm teamordner teamcall teammeeting file efdl users linnes collaboration platform company inc teamordner linnemann teamcall teammeeting top projekte file efdl users linnes collaboration platform company inc teamordner linnemann top projekte hallo sabrthy wie weit sind wir diesem thema habe noch kein ticket erhalten mit freundlichen anwendungstechniker application engineer company deutschland gmbh diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung select the following link view the disclaimer alternate language von gesendet donnerstag juli betreff access netweaver danke sabrthy mit freundlichen anwendungstechniker application engineer diese mitteilung ist einzig und allein die nutzung durch den adressaten bestimmt und kann informationen enthalten die schutzw rdig vertraulich oder nach geltendem recht von der offenlegung ausgenommen sind die verbreitung verteilung oder vervielf ltigung dieser mitteilung durch personen bei denen sich nicht die beabsichtigten empf nger handelt ist streng verboten wenn diese mitteilung aufgrund eines versehens bei ihnen eingegangen ist dann benachrichtigen sie bitte den absender und schen sie diese mitteilung select the following link view the disclaimer alternate language von gesendet donnerstag juli betreff access netweaver hallo stepfhryhan das nimmt ein bisschen zeit ich erfasse ein ticket dazu warm
#
#
#
# nwfodmhc exurcwkm johthryugftyson kds services rad order team kindly please assist unable create for hydstheud mddwwyleh operation supervisor company distribution services asia pte ltd asia regional distribution centre email johthryugftyson kds mmaster kds services order din please create ticket for help juhu jojfufn logistics manager kds mmaster kds services johthryugftyson order zadnryuinudin rqfhiong zkwfqagb team can only create sto are not authorized create plant warehouse persons can create for the sto
#
#
#
# probleme mit drucker uacyltoe hxgayczeraum reinhard ger
#
#
#
# security error reisekosten abrechnungs programdnty
#
#
#
# langsamer rechner berpr fung
#
#
#
# bluetooth keybankrd defekt dardabthyr
#
#
#
# probleme mit bildschirmschoner
#
#
#
# mobiltelefon gigaset professional mit der durchwahl akku defekt nicht mehr nger wie tag display kann man kaum noch was erkennen clip defekt
#
#
#
# ich wei mein erp passwort nicht mehr und habe fehlversuche eingegeben bitte zur cksetzen
#
#
#
# user vvrtgwildj name johghajknnes wildschuetz user logging for the first time and getting error die sicherheisdatenbank auf dem server enth kein computerkonto diese arbeitsstationsvertrauensstellung error the security database the server does not contain computer account for this workstation trust relationship computer name efdl contact
#
#
#
# error message laufzeitfehler ung ltige verwendung von null prompted step auftragsausgang von revision freigegeben pressing okay results programdnty crash error occured first time this morning cet there one batch this step von revision freigegeben the moment batches after that stage the workflow can processed usual however workflow interrupted and batches directly before critical stage can further processed happens only for pvd cvd running without any issues
#
#
#
# der drucker steht platz von
#
#
#
# nwfodmhc exurcwkm die synchronisierung mit exchange activesync ist auf ihrem ger vor bergehend blockiert bis der zugriff vom administrator gew hrt wird importance high help team please unblock new company device
#
#
#
# mehreren lassen sich verschiedene prgramdntyme nicht ffnen bereich cnc

# %%
translateIfRequired('sich')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-7d0ca5cbe647> in <module>
# ----> 1 translateIfRequired('sich')
#
# <ipython-input-82-999358646bf4> in translateIfRequired(x)
#       6 def translateIfRequired(x):
#       7     translator = Translator()
# ----> 8     if translator.detect(x).lang != 'en':
#       9         translatedText = translator.translate(x).text
#      10     else:
#
# C:\python\anaconda3\lib\site-packages\googletrans\client.py in detect(self, text, **kwargs)
#     253
#     254         :rtype: Detected
# --> 255         :rtype: :class:`list` (when a list is passed)
#     256
#     257         Basic usage:
#
# C:\python\anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src, override)
#      76             self.token_acquirer = TokenAcquirer(
#      77                 client=self.client, host=self.service_urls[0])
# ---> 78
#      79             #if we have a service url pointing to client api we force the use of it as defaut client
#      80             for t in enumerate(service_urls):
#
# C:\python\anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     192         if a < 0:  # pragma: nocover
#     193             a = (a & 2147483647) + 2147483648
# --> 194         a %= 1000000  # int(1E6)
#     195
#     196         return '{}.{}'.format(a, a ^ b)
#
# C:\python\anaconda3\lib\site-packages\googletrans\gtoken.py in _update(self)
#      60
#      61         try:
# ---> 62             # this will be the same as python code after stripping out a reserved word 'var'
#      63             code = self.RE_TKK.search(r.text).group(1).replace('var ', '')
#      64             # unescape special ascii characters such like a \x3d(=)
#
# AttributeError: 'NoneType' object has no attribute 'group'
